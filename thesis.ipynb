# %% [raw]
# ---
# title: "TBD"
# author: "TBD"
# program: "Fizyka Techniczna"
# faculty: "Wydział Fizyki i Informatyki Stosowanej"
# department: "Katedra ..."
# thesis-type: "Praca magisterska"
# lang: en
# format:
#   agh-thesis-pdf: default
# execute:
#   enabled: true
# bibliography: refs.bib
# ---

# %%
#| include: false

# enforcing inline vector graphics
# %config InlineBackend.figure_format = 'svg'

# trigger font manager cache rebuild
from matplotlib import figure
figure.Figure()

# AGH colours + colour-blind-safe linestyles + font sizes  
import matplotlib
from cycler import cycler
matplotlib.rcParams.update({
    "axes.prop_cycle": cycler(color=('#A71930', '#00693C', '#1E1E1E')) + cycler(linestyle=("-", "--", ":")),
    "lines.linewidth": 1.5,
    "lines.markersize": 3,
    "axes.grid": False,
    "font.size": 12,
    "axes.labelsize": 12,
    "axes.titlesize": 14,
    "legend.fontsize": 11,
    "xtick.labelsize": 11,
    "ytick.labelsize": 11,
    "figure.figsize": (5, 3.5),
    "legend.handlelength": 1.0
})

# %%
#| include: false
with open("refs.bib", "w") as f:
    f.write(r"""
@inproceedings{vanRossum_1998,
  year         = {1998},
  author       = {van Rossum, Guido},
  title        = {Glue It All Together With {Python}},
  url          = {https://web.archive.org/web/19980614041513/http://www.objs.com/workshops/ws9801/papers/paper070.html},
  booktitle    = {OMG-DARPA-MCC Workshop on Compositional Software Architecture},
  address      = {Monterey, California, January 6-8, 1998}
}
""")

# %% [markdown]
# # Introduction
#
# ## Subsection containing code listing

# %%
from datetime import datetime
print(datetime.now().strftime("%x %X"))
# Out:
# 04/23/26 15:38:33

# %% [markdown]
# ## Subsection containing a plot

# %%
#| label: fig-sin
#| fig-cap: "Sinusoid & co."

from matplotlib import pyplot
import numpy as np
pyplot.plot(x := np.linspace(-2*np.pi, 2*np.pi, 100), np.sin(x))
pyplot.plot(x, np.cos(x))
pyplot.plot(x, np.sin(x)*np.cos(x));

# %% [markdown]
# # Results
#
# Let us cite [@vanRossum_1998]

# %% [markdown]
# # Conclusions
#
# ## Subsection containing an equation
#
# \begin{equation}
#   \sin x = \sum_{n=0}^{\infty} (-1)^n \frac{x^{2n+1}}{(2n+1)!}
# \end{equation}
